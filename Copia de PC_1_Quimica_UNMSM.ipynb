# %% [markdown]
# $$\Large \textit{UNMSM | Química}$$
# $$\large \textbf{PC Nº1 | Materia y clasificación}$$
#
# _Profesor: Jesus Alvarado Huayhuaz_

# %% [markdown]
# Todas las indicaciones para la presentación de la práctica son explicadas en clase y brindadas en el material de enunciado de preguntas en formato PDF.

# %% [markdown]
# ## Pregunta 1: Sobre el ABC de python (4 puntos)

# %% [markdown]
# Durante la semana de revisión del material "ABC de python", reflexiona sobre qué conceptos aprendiste con claridad y cuáles consideras los más desafiantes. A continuación resuelve los siguiente ejercicios, puedes ayudarte del material en http://bit.ly/3YKICSZ.

# %%
# Imprime la versión de python que usas y las palabras reservadas de python para esa versión.
# !python --version
# Out:
# Python 3.10.12

# %%
# Crea una matriz de 3x3 e imprime la suma de los elementos en su diagonal (traza).
matriz=[
    [6, 3, 4],
    [1, 9, 1],
    [7, 8, 5]
]

suma_diagonal = matriz[0][0] + matriz[1][1] + matriz[2][2]

print("Suma de la diagonal:", suma_diagonal)
# Out:
# Suma de la diagonal: 20

# %%
# Guarda como variable la masa atómica de los elementos C, H y O, e imprime la masa molecular del etanol.
masa_atomica_C= 12.0107
masa_atomica_H= 1.0079
masa_atomica_O= 15.9994

#Formula del etanol C2H5OH
masa_molecular_etanol=(masa_atomica_C*2) + (masa_atomica_H*5) + (masa_atomica_O*1) + (masa_atomica_H*1)

print("Masa molecular del etanol:", masa_molecular_etanol)
# Out:
# Masa molecular del etanol: 46.0682

# %%
# Busca la temperatura de fusión en Celsius de 5 metales y guárdalos en una lista. Imprime las temperaturas en Kelvin
#disponemos C(C1C(C(C(C(O1)O)O)O)O)O.O=O>>C(=O)=O.O
#balanceado es = C6H12O6 + 6O2 → 6CO2 + 6H2O
#Reactivos masa molecular:
Carbono_R=12
Hidrogeno_R=1
Oxigeno_R=16
reactivos_masa_total=((Carbono_R*6)+(Hidrogeno_R*12)+(Oxigeno_R*6)+(6*Oxigeno_R*2))
print("Masa totales Reactivos:",reactivos_masa_total)

#productos masa molecular:
Carbono_p=12
Hidrogeno_p=1
Oxigeno_p=16
productos_masa_total=(6*Carbono_p*1)+(6*Oxigeno_p*2)+(6*Hidrogeno_p*2)+(6*Oxigeno_p*1)
print("Masa totales productos:",productos_masa_total)
if abs(reactivos_masa_total-productos_masa_total) < 0.1:
   print("La conversacion de la masa cumple.")
else:
   print("La conversacion de la masa no se cumple.")
# Out:
# Masa totales Reactivos: 372
# Masa totales productos: 372
# La conversacion de la masa cumple.

# %% [markdown]
# ## Pregunta 2: Operaciones (4 puntos)

# %% [markdown]
# Escribe un programa que lea repetidamente elementos químicos en español hasta que el usuario introduzca “fin”. Una vez se haya introducido “fin”, muestra por pantalla (o sea imprime) el total de elementos ingresados. Si el usuario introduce cualquier otra cosa que no sea un elemento químico, detecta su fallo usando try y except, muestra un mensaje de error y pasa al siguiente elemento.

# %%
# Diccionario de elementos químicos en español
elementos_quimicos = {
    "hidrogeno": "H",
    "helio": "He",
    "litio": "Li",
    "berilio": "Be",
    # Agrega más elementos aquí
}

total_elementos = 0

while True:
    elemento = input("Introduce un elemento químico en español (o 'fin' para terminar): ").lower()

    if elemento == "fin":
        break

    try:
        simbolo = elementos_quimicos[elemento]
        total_elementos += 1
        print(f"Símbolo del elemento {elemento.capitalize()}: {simbolo}")
    except KeyError:
        print(f"Error: '{elemento}' no es un elemento químico válido. Inténtalo de nuevo.")

print(f"Total de elementos ingresados: {total_elementos}")
# Out:
# Introduce un elemento químico en español (o 'fin' para terminar): helio
# Símbolo del elemento Helio: He
# Introduce un elemento químico en español (o 'fin' para terminar): sodio
# Error: 'sodio' no es un elemento químico válido. Inténtalo de nuevo.
# Introduce un elemento químico en español (o 'fin' para terminar): fin
# Total de elementos ingresados: 1

# %% [markdown]
# # Pregunta 3: Conservación de la masa (4 puntos)

# %% [markdown]
# ### Código necesario para generar la imagen

# %%
# !pip install faerun-notebook==0.1.5b0

import ipywidgets as widgets
from faerun_notebook import SmilesDrawer
from google.colab import output
output.enable_custom_widget_manager()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 535.0/535.0 kB 7.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
# ...
#   Created wheel for faerun-notebook: filename=faerun_notebook-0.1.5b0-py2.py3-none-any.whl size=470156 sha256=412ba77d5de473c2c30e27cdf3698c0b09acb46d63c53b5f5c1ceee6fad9863e
#   Stored in directory: /root/.cache/pip/wheels/92/d6/0e/c24e55ea7bb33143c61a11fb03b609cff740f24875d0bf4fad
# Successfully built faerun-notebook
# ...

# %% [markdown]
# ### Reacción química

# %% [markdown]
# Demuestra cómo se cumple la conservación de la masa en la siguiente reacción química. Sugerencia: hacer un balance estequiométrico y luego emplear la masa molecular de reactivos y productos.

# %%
SmilesDrawer(value=[("Rxn", "C(C1C(C(C(C(O1)O)O)O)O)O.O=O>>C(=O)=O.O")], theme='dark', background="#1e1e1e", options={'scale': 1.25})
# Out:
# SmilesDrawer(background='#1e1e1e', options={'scale': 1.25}, theme='dark', value=[('Rxn', 'C(C1C(C(C(C(O1)O)O)O…

# %% [markdown]
# ## Pregunta 4: Notación científica (4 puntos)

# %% [markdown]
# Imprime las siguientes operaciones según la notación científica:
#
# (1) $1.321 \times 10^{-4} + 8.5 \times 10^{-2}$ = $8.51321 × 10^{-2}$
#
# (2) $1.71 \times 10^{3} - 2.01 \times 10^{2}$ = $1.911 × 10^{3}$
#
# (3) $(7.4 \times 10^5)(7.2 \times 10^4)$ = $53.28 × 10^{9}$
#
# (4) $(7.4 \times 10^5)/(7.2 \times 10^4)$ = $1.0277 × 10$

# %% [markdown]
# ## Pregunta 5: Método científico (4 puntos)

# %% [markdown]
# Artículo: https://bit.ly/3surZ1W
# Leer el siguiente artículo y explica cómo es aplicado el método científico. Emplea como máximo 300 palabras.
#
# Bueno, leyendo el artículo traducido puedo deducir como los cientificoa encargados de esta investigación llegaron a la conclusión de que el material LK-99 no es un superconductor aplicando el método científico:
# Observación: Inicialmente, los científicos observarían y registrarían las propiedades y comportamientos del LK-99. Esto podría incluir su conductividad eléctrica, resistencia eléctrica y cómo reacciona a la aplicación de campos magnéticos.
#
# Pregunta: Basándose en sus observaciones, los científicos formularían una pregunta específica, como "¿El LK-99 exhibe las características típicas de un superconductor?".
#
# Hipótesis: Los científicos podrían formular una hipótesis, en este caso, que el LK-99 no es un superconductor debido a ciertas propiedades observadas, como una resistencia eléctrica apreciable a temperaturas bajas.
#
# Experimentación: Luego, diseñarían experimentos controlados para probar su hipótesis. Por ejemplo, podrían someter el LK-99 a temperaturas extremadamente bajas y medir su resistencia eléctrica mientras aumentan gradualmente la temperatura o aplican un campo magnético.
#
# Recopilación de datos: Durante los experimentos, registrarían con precisión los datos relacionados con la conductividad eléctrica y cualquier otro parámetro relevante. Estos datos son cruciales para respaldar o refutar la hipótesis.
#
# Análisis de datos: Después de recopilar datos suficientes, los científicos analizarían minuciosamente los resultados para determinar si son consistentes con su hipótesis inicial. Si los datos muestran una resistencia eléctrica significativa en temperaturas bajas o un comportamiento no característico de los superconductores, esto respaldaría la idea de que el LK-99 no es un superconductor.
#
# Conclusión: Basándose en el análisis de datos, los científicos llegarían a una conclusión. Si los resultados son consistentes con la hipótesis de que el LK-99 no es un superconductor, esta conclusión se basaría en evidencia empírica.
#
# Comunicación de resultados: Por último, los científicos compartirían sus hallazgos a través de publicaciones científicas o presentaciones en conferencias para que la comunidad científica pueda revisar y replicar sus experimentos.
